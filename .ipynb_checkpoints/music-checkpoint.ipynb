# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load And Read The Data Receive Into a Pandas DataFrame

# %%
data = pd.read_csv('music.csv')
data.tail()
# Out:
#                   Artist Name  \
# 8742                blink-182
# 8743                  Beloved
# 8744              Saint Louis
# 8745    The Smashing Pumpkins
# 8746  Van Der Graaf Generator
#
#                                              Track Name  Popularity  \
# 8742                                         I Miss You           0
# 8743                                 Failure On My Lips          37
# 8744                                      Carry Me Away          35
# 8745                                Disarm - Remastered          64
# 8746  A Plague Of Lighthouse Keepers (Medley) - 2005...          29
#
#                                                  Genres            Playlist  \
# 8742             ['pop punk', 'punk', 'socal pop punk']    00s Rock Anthems
# 8743                                                 []       2000s Screamo
# 8744                                                 []          Rocktronic
# ...

# %% [markdown]
# ## Analyze Dataset

# %%
data.describe()
# Out:
#         Popularity  danceability       energy          key     loudness  \
# count  8747.000000   8747.000000  8747.000000  8747.000000  8747.000000
# mean     48.797645      0.502520     0.742130     5.259746    -6.835121
# std      18.401529      0.136813     0.192597     3.512935     3.177930
# min       0.000000      0.000000     0.009760     0.000000   -24.361000
# 25%      37.000000      0.411000     0.629000     2.000000    -8.427500
# 50%      50.000000      0.507000     0.789000     5.000000    -6.097000
# 75%      63.000000      0.595000     0.900000     8.000000    -4.569000
# max      93.000000      0.975000     0.999000    11.000000     1.355000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  8747.000000  8747.000000   8747.000000       8747.000000  8747.000000
# mean      0.664685     0.062246      0.126006          0.081875     0.206974
# std       0.472127     0.051713      0.217552          0.207497     0.165069
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8747 entries, 0 to 8746
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist Name       8747 non-null   object
#  1   Track Name        8747 non-null   object
#  2   Popularity        8747 non-null   int64
#  3   Genres            8747 non-null   object
#  4   Playlist          8747 non-null   object
#  5   danceability      8747 non-null   float64
#  6   energy            8747 non-null   float64
#  7   key               8747 non-null   int64
#  8   loudness          8747 non-null   float64
#  9   mode              8747 non-null   int64
#  10  speechiness       8747 non-null   float64
#  11  acousticness      8747 non-null   float64
#  12  instrumentalness  8747 non-null   float64
#  13  liveness          8747 non-null   float64
#  14  valence           8747 non-null   float64
#  15  tempo             8747 non-null   float64
# ...

# %%
data.mean()
# Out:
# Popularity              48.797645
# danceability             0.502520
# energy                   0.742130
# key                      5.259746
# loudness                -6.835121
# mode                     0.664685
# speechiness              0.062246
# acousticness             0.126006
# instrumentalness         0.081875
# liveness                 0.206974
# valence                  0.494039
# tempo                  125.783093
# duration_ms         239448.689151
# time_signature           3.946953
# dtype: float64

# %% [markdown]
# ## Popularity Vs Tempo

# %%
x = data['Popularity'].values
y = data['tempo'].values
plt.figure() # Space to Plot
plt.plot(x, label='Popularity', color='red')
plt.plot(y, label='tempo')
plt.legend() # To Show The Labels
plt.title('Rock Music')
plt.xlabel('Popularity')
plt.ylabel('tempo')
plt.show() # Show The Plot

# %% [markdown]
# ## What Are The Highest Liveness ?

# %%
sns.violinplot( x1 = 'Artist Name' , y1 = 'liveness' , data = data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion
# reading and import the data
# Compaire between Popularity  and danceability so close and related
# the highest liveness betweenn **1 - 0**
# Full discription about the data
